# %%
from sklearn import tree 
from sklearn.datasets import load_iris 
import graphviz 
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import GridSearchCV


from  math import sqrt

# %%
iris = load_iris()

#chargement des données IRIS de sickit-learn

df = pd.DataFrame(iris.data)
df.columns = ["sl", "sw", 'pl', 'pw']
y = pd.DataFrame(iris.target)
y.columns = ['target']


print(df.head())
#calcul de la moyenne des différents colonnes du dataset

mean_sl = df["sl"].sum()/150
mean_sw = df["sw"].sum()/150
mean_pl = df["pl"].sum()/150
mean_pw = df["pw"].sum()/150



#affichage des valeurs de la moyenne 

print('mean_sl  =  ',mean_sl,"  ",'mean_sw  =  ',mean_sw,"  ",'mean_pl  =  ',mean_pl,"  ",'mean_pw  =  ' ,mean_pw,"  ")

#calcul de l'écart type des différents colonnes du dataset

std_sl = sqrt(((df["sl"] - mean_sl)**2).sum()/len(df))
std_sw = sqrt(((df["sl"] - mean_sw)**2).sum()/len(df))
std_pl = sqrt(((df["sl"] - mean_pl)**2).sum()/len(df))
std_pw = sqrt(((df["sl"] - mean_pw)**2).sum()/len(df))

#affichage des valeurs de l'écat type 
              
print('std_sl  =  ',std_sl,"  ",'std_sw  =  ',std_sw,"  ",'std_pl  =  ',std_pl,"  ",'std_pw  =  ' ,std_pw,"  ")

#ou sinon on pourra le faire avec la méthode pd.describe() pour avoir plus d'info statistiques

df.describe()
# Out:
#     sl   sw   pl   pw
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2
# mean_sl  =   5.843333333333334    mean_sw  =   3.0573333333333337    mean_pl  =   3.7580000000000005    mean_pw  =   1.1993333333333336
# std_sl  =   0.8253012917851409    std_sw  =   2.905670012617094    std_pl  =   2.2427075897970585    std_pw  =   4.716763532574239
#                sl          sw          pl          pw
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333
# std      0.828066    0.435866    1.765298    0.762238
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#Question when needed to split data and get score of prediction 
clf = tree.DecisionTreeClassifier()
iris = load_iris() 
X, y = iris.data, iris.target 

X_train,  X_test,  y_train,  y_test  =  train_test_split(X,  y,  test_size=0.95,random_state=0)
clf.fit(X_train, y_train)

clf.predict(X_test)
tree.plot_tree(clf,filled = True)

print("the score of prediction  when the test_size = 95% is  :  ")
clf.score(X_test, y_test)
# Out:
# the score of prediction  when the test_size = 95% is  :
# 0.8111888111888111

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'max_depth':[1,5,10,50,100], 'min_samples_leaf':[10,20,30,40,50] }

grid_obj = GridSearchCV( clf, parameters)
grid_fit = grid_obj.fit(X, y)

print(grid_fit.best_params_)
print(" the score is about : ")
grid_fit.score(X_test, y_test)
# Out:
# {'max_depth': 5, 'min_samples_leaf': 10}
#  the score is about :
# 0.958041958041958

# %%
import numpy as np 
import matplotlib.pyplot as plt 
 
# Paramètres 
n_classes = 3 
plot_colors = "bry" # blue-red-yellow 
plot_step = 0.02 
 
# Choisir les attributs longueur et largeur des pétales 
pair = [1,2] 
 
# On ne garde seulement les deux attributs 
X = iris.data[:, pair] 
y = iris.target 
 
# Apprentissage de l'arbre 
clf = tree.DecisionTreeClassifier().fit(X, y) 
 
# Affichage de la surface de décision 
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1 
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1 
xx,  yy  =  np.meshgrid(np.arange(x_min,  x_max,  plot_step),  np.arange(y_min, 
y_max, plot_step)) 
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()]) 
Z = Z.reshape(xx.shape) 
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.Paired) 
plt.xlabel(iris.feature_names[pair[0]]) 
plt.ylabel(iris.feature_names[pair[1]]) 
plt.axis("tight") 
 
# Affichage des points d'apprentissage 
for i, color in zip(range(n_classes), plot_colchargez la base de données Diabètesors): 
    idx = np.where(y == i) 
    plt.scatter(X[idx,  0],  X[idx,  1],  c=color,  label=iris.target_names[i], 
cmap=plt.cm.Paired) 
plt.axis("tight") 
plt.suptitle("Decision surface of a decision tree using features [1,0]") 
plt.legend() 
plt.show()

# %%
from sklearn import tree 
 
X = [[0, 0], [2, 2]] 
y = [0.5, 2.5] 
clf = tree.DecisionTreeRegressor() 
clf = clf.fit(X, y) 
clf.predict([[1, 1]])

import numpy as np 
import matplotlib.pyplot as plt 
 
from sklearn.tree import DecisionTreeRegressor 
 
# Créer les données d'apprentissage 
np.random.seed(0) 
X = np.sort(5 * np.random.rand(80, 1), axis=0) 
y = np.sin(X).ravel() 
 
fig = plt.figure(figsize=(12, 4)) 
fig.add_subplot(121) 
plt.plot(X, y) 
plt.title("Signal sinusoïdal pur") 
 
# On ajoute un bruit aléatoire tous les 5 échantillons 
y[::5] += 3 * (0.5 - np.random.rand(16)) 
fig.add_subplot(122) 
plt.plot(X, y) 
plt.title("Signal sinusoïdal bruité")
# Out:
# Text(0.5, 1.0, 'Signal sinusoïdal bruité')

# %%
# Apprendre le modèle 
reg = DecisionTreeRegressor(max_depth=1) 
reg.fit(X, y) 
 
# Prédiction sur la même plage de valeurs 
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis] 
y_pred = reg.predict(X_test) 
 
# Affichage des résultats 
plt.figure() 
plt.scatter(X, y, c="darkorange", label="Exemples d'apprentissage") 
plt.plot(X_test, y_pred, color="cornflowerblue", label="Prédiction", linewidth=2) 
plt.xlabel("x") 
plt.ylabel("y") 
plt.title("Régression par un arbre de décision") 
plt.legend() 
plt.show() 
 
#Question : Quand on augmente la valeur de max_depth, on remarque que notre modéle est dans le sur_apprentissage (overfiting)
# en revanche quand on diminue cette valeur on peut observer que notre modéle est dans sous_apprenstissage (underfiting)
